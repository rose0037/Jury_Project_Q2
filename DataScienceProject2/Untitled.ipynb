# %%
# %matplotlib inline

# %%
run DataLoadingCleaning.py
# Out:
# Start Date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        object
# ...
